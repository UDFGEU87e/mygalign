# %%
import json
with open('./yale1/graphsage/G.json', 'r') as f:
    data1 = json.load(f)

# %%
edge_set1=set()
for i in data1['links']:
    edge_set1.add((i['source'],i['target']))

# %%
edge_set1
# Out:
# {(4804, 7178),
#  (209, 5386),
#  (1503, 3855),
#  (1620, 4768),
#  (6054, 7107),
#  (658, 2480),
#  (5468, 7572),
#  (3744, 6437),
#  (77, 5320),
#  (1830, 5548),
#  (4790, 6423),
#  (2220, 4960),
#  (4715, 7039),
#  (1792, 5223),
#  (2335, 7308),
#  (3586, 8384),
#  (1693, 5538),
#  (3749, 7066),
#  (2307, 5136),
#  (5522, 5758),
#  (1093, 4610),
#  (1710, 7080),
#  (5466, 6732),
#  (181, 691),
#  (3460, 4892),
#  (299, 7659),
#  (1677, 1869),
#  (5124, 8563),
#  (1180, 4950),
#  (2896, 7964),
#  (2104, 8184),
#  (6638, 6677),
#  (3443, 5613),
#  (6914, 8377),
#  (3073, 8413),
#  (2661, 5085),
#  (5307, 6390),
#  (4095, 4742),
#  (2207, 5704),
#  (1358, 8400),
#  (3371, 4745),
#  (3381, 7869),
#  (4144, 4572),
#  (599, 8436),
#  (4559, 6113),
#  (3, 4626),
#  (3359, 4653),
#  (1493, 3530),
#  (4199, 4670),
#  (1424, 5455),
#  (5316, 7576),
#  (1381, 3201),
#  (4298, 7446),
#  (3362, 7386),
#  (2104, 2249),
#  (670, 794),
#  (140, 257),
#  (1493, 1903),
#  (2101, 3855),
# ...

# %%
import json
with open('./yale2/graphsage/G.json', 'r') as f:
    data2 = json.load(f)

# %%
edge_set2=set()
for i in data2['links']:
    edge_set2.add((i['source'],i['target']))

# %%
len(edge_set1&edge_set2)
# Out:
# 198668
